# %% [markdown]
# <a href="https://colab.research.google.com/github/YadielCruz/IRML-CER3D_Dataset/blob/main/Module_1_Loading_IR_Spectra_for_Classification_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Integrating Machine Learning into Chemistry Education: Classifying IR Spectra of Disubstituted Aromatics as an Introductory ML Exercise.**

# %% [markdown]
# # Module 1: Loading IR Spectra for Classification Models

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# Objectives:
#
#
# 1.   Undestand what is machine learning
#
# 2.   Know how to manipulate a data set by using the librarie pandas.
#
# 3.   Understand the leanrning process of a machine learning model and how does it read a data set.

# %% [markdown]
# **What is machine learning?**
#
# Machine learning (ML) is a branch of artificial intelligence in which algorithms identify patterns and generate predictions from data. ML provides a rich context for developing skills such as problem decomposition, coding fluency, and model evaluation. Engaging students in the process of training an ML model therefore offers an authentic opportunity to foster computational thinking and data interpretation while simultaneously strengthening technological literacy.
#
# There are many types of models, also known as mathematical algorithms, ranging from the most basic and easy to visualize and understand the math behind to more complex and high-dimensional models.
#
# In this series of modules, we will focus on the most basic multiclass algorithm to learn, K-nearest neighbor. We will learn how it works, how to use it, and how to optimize it to achieve the best results when classifying a series of ortho-, meta-, and para-compound IR spectra.

# %% [markdown]
# **What does a machine learning model need to succeed?**
#
#
# **A data set**
#
#  * Every machine learning model requires a suitable dataset to perform predictions or classifications. This project is no exception; it draws upon the work of Cahill et al., which provides a dataset comprising a total of 380 infrared spectra of disubstituted aromatic compounds. These spectra were obtained using a Shimadzu IRSpirit Fourier-transform infrared (FTIR) spectrophotometer equipped with a QATR-S attenuated total reflectance (ATR) accessory. Each spectrum represented an average of 10 scans, collected within the 400–4000 cm⁻¹ range at a resolution of 0.9 cm⁻¹. For each compound analyzed via infrared spectroscopy, five independent measurements were performed using five samples of the same compound; consequently, the dataset contains five spectra for each compound. In total, the dataset consists of 76 disubstituted benzene compounds—21 *ortho*, 22 *meta*, and 33 *para*—with five spectral replicates for each. We will use this dataset to train and test the machine learning models that we will use to classify these spectra.
#
# **The dataset can be located in a folder in the GitHub repository titled Data - Raw IR Spectra. In here, you will find all spectra in .txt format.**

# %% [markdown]
# ## 2. Importing Pandas

# %% [markdown]
# For our model to succeed in classifying spectra, we will implement the dataset provided in the repository. This dataset needs to be preprocessed for our model to understand the data effectively. That's why we first need to learn how to explore and preprocess data by using the Pandas library. Pandas is a Python library that allows us to work with data in table format. Its main structure is called a DataFrame, which works similarly to an Excel table because it contains rows and columns.
#
# In this module, Pandas will be used to:
#
# 1. Load a spectrum from a .txt file
# 2. View the first rows of a dataframe
# 3. Identify and understand the columns in the dataset
# 4. Remove unnecessary header rows
# 5. Add meaningful column names based on the wavenumber values
#
# We begin by importing the Pandas library, which is already available in Google Colab. Using the keyword as, we can assign it a shorter name to make our code easier to read and write.
#
# Example:
#
#
# ```
# import pandas as pd
# ```
#
# Now try importing it yourself!

# %%
#Code here!
#--------------------------------

#--------------------------------

# %% [markdown]
# ## 3. Loading the Data

# %% [markdown]
# Due to the complexity of having a total of 380 spectra, we will first load one spectrum, and then we will apply the same process to all spectra.
#
# To load a .txt file in Google Colab, we declare the following function:
# ```
# DataFrame = pd.read_csv('file_directory.txt')
# ```
# We can get the file directory by just right-clicking one of the .txt spectra files and copying its path into the function. Now it's your turn; try to import pandas and load a .txt spectrum file of your choosing from the folder in the repository. Try to see what the code tells you when you run it!
#
# **Use the function DataFrame.head() to see the first 5 rows of the table.**

# %%
#Code here!
#--------------------------------





#--------------------------------

# %% [markdown]
# ## 4. Loading the Infrared Spectrum Data Correctly

# %% [markdown]
# After looking at the raw infrared spectrum data, we can see that the file is not organized like a normal table. The file contains extra text at the beginning, such as the title, data type, and units. It also contains the actual numerical data for the spectrum.
#
# What you are seeing is the raw data of an infrared spectrum. An infrared spectrum is a two-dimensional graph made up of x and y coordinates. In this case, the x-axis represents the wavenumber, usually measured in cm⁻¹, and the y-axis represents percent transmittance, written as %T. At first, the raw data may look confusing because both values appear together in the same row. However, the first value in each row corresponds to the wavenumber, and the second value corresponds to the percent transmittance.
#
#
# To load this .txt file correctly, we use the following code:
#
#
#
# ```
# df = pd.read_csv( 'path',  index_col='Wavenumber/cm-1',names=["Wavenumber/cm-1","% Transmittance"],skiprows=4,delimiter=r"\s+")
# ```
#
# As you can see, we now used 4 new parameters for the read_csv function. Let's see what this new parameters are use for:
#
#
# * index_col='Wavenumber/cm-1' : Sets the Wavenumber/cm-1 column as the DataFrame index. This allows the wavenumber values to act as row labels instead of a regular data column.
#
# * names=["Wavenumber/cm-1", "% Transmittance"] : Assigns names to the columns when the file does not contain a header row or when you want to replace the existing column names.
#
# * skiprows=4 : Skips the first 4 rows of the file. These rows contain metadata (such as the title and units) rather than the numerical spectrum data.
#
# * delimiter=r"\s+" : Tells Pandas that the values are separated by one or more whitespace characters (spaces or tabs). This allows Pandas to correctly split each line into separate columns.
#
#
# It is important to understand that every dataset you encounter may be formatted differently. Some files use commas to separate values, while others use spaces, tabs, or other delimiters. Some datasets may also contain metadata that you want to skip before reading the actual data.
#
# Because every dataset is unique, it is important to first understand its structure and then check the documentation to find the appropriate parameters for loading it correctly. The official Pandas documentation is an excellent resource if you have additional questions or need to explore more options.
#
# https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
#
# Now try to load your dataframe correctly! Remember to use the .head function to always see the first rows of your dataframe.

# %%
#Code here!
#--------------------------------





#--------------------------------

# %% [markdown]
# **Now if you got it all right you are suppose to get something like this:**
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 5. Vizualizing a Dataset with matplotlib

# %% [markdown]
# Sometimes having just a table of data isn't enough to say for sure that we loaded the data correctly. That's why it's important to have a way to visualize this data and be sure it's loaded correctly.
#
#
#
# There are many Python libraries dedicated to the visualization of data. For this module, we will be covering the basics of visualizing data using Matplotlib. Matplotlib is a Python library used to create graphs and data visualizations. It provides a simple interface for generating a wide variety of plots, such as line graphs, bar charts, scatter plots, histograms, and many others. Since it is built on top of NumPy, it works efficiently with numerical data and is widely used in data analysis and machine learning.
#
#
#
#
# To visualize the DataFrame for our selected spectrum, we first need to import the plotting tools. This requires importing the pyplot module, which allows us to create graphs and figures.
#
#
# ```
# import matplotlib.pyplot as plt
# ```
#
# The alias plt is simply a shorter name for matplotlib.pyplot. Using this alias is the standard convention in Python, making plotting commands shorter and easier to read.
#
#
# To create a graph, we need to understand how our DataFrame is organized. A Pandas DataFrame consists of one or more Series, where each Series represents a column of data. Matplotlib can use these Series as the x- and y-coordinates of a graph.
#
# In our DataFrame, we can attribute the x- coordinates to the index/wavenumber column of our DataFrame, just like any other infrared spectra. And then we can get the transmittance column for the y- axis.
#
# Example:
#
# ```
# #To create a 2d plot we use the following function
# plt.plot(df['x- coordinates'] , df['y- coordinates'])
#
# #In other to see the plot we use...
# plt.show()
# ```
# Now your turn!
#
# Try to create a plot where the x- coordinates are the column name 'Wavenumber/cm-1' and the y- coordinates '% Transmittance'. Remeber when calling a series of a pandas dataframe we use ['column name']. When we want to use the index of a pandas dataframe, instead of using ['column name'] we use the atribute .index.

# %%
#Code here!
#--------------------------------







#--------------------------------

# %% [markdown]
# So far so good, if the code is correctly written we are suppose to see a graph of the infrared spectra we loaded.
#
# There are other things one can add and change to the graph such as title, axis names, colors, grid, style, size, etc. For this module, we will remain simple in terms of ploting. However here is an example of a graph could look like.
#
#
#
# ```
# import matplotlib.pyplot as plt
# df = pd.read_csv( 'path',names=["Wavenumber/cm-1","% Transmittance"],skiprows=4,delimiter=r"\s+")
# plt.style.use('ggplot')
# plt.plot(df.index , df['% Transmittance'], c = 'green')
# plt.title('Acetoxybenzoic Spectra')
# plt.xlabel('Wavenumber/cm-1')
# plt.ylabel('% Transmittance')
# plt.grid(True)
# plt.show()
# ```
#
#
#
# ![image.png](data:image/png;base64,...)
#
# If you are interested in learning more in depht in ploting and data visualization in matplotlib, you can always check the documentation.
#
#
# https://matplotlib.org/stable/index.html
